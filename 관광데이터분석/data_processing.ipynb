# %% [markdown]
# ### 관광객 데이터 전처리

# %% [markdown]
# ### 데이터 로드

# %%
# kto_201901.xlsx 불러오기
# 컬럼명과 컬럼 데이터만 불러오기

# %%
import pandas as pd
import matplotlib as mpl # 그림 그리기
import matplotlib.pylab as plt # 그림 그리기
import seaborn as sns 
import numpy as np

# %%
file_path = './files/kto_201901.xlsx'
kto_201901 = pd.read_excel(file_path
                           , header = 1
                           , skipfooter = 4
                           , usecols = 'A:G') # df = pd.read_csv(file_path, encoding = 'euc-kr')
kto_201901
# Out:
#          국적      관광     상용    공용  유학/연수      기타       계
# 0      아시아주  765082  10837  1423  14087  125521  916950
# 1        일본  198805   2233   127    785    4576  206526
# 2        대만   86393     74    22    180    1285   87954
# 3        홍콩   34653     59     2     90    1092   35896
# 4       마카오    2506      2     0     17      45    2570
# ..      ...     ...    ...   ...    ...     ...     ...
# 62  아프리카 기타     768    718    90    206     908    2690
# 63     기타대륙      33      4     0      1      16      54
# 64     국적미상      33      4     0      1      16      54
# 65     교포소계       0      0     0      0   15526   15526
# 66       교포       0      0     0      0   15526   15526
#
# [67 rows x 7 columns]

# %%
kto_201901.info() # 기본 정보 및 null 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국적      67 non-null     object
#  1   관광      67 non-null     int64
#  2   상용      67 non-null     int64
#  3   공용      67 non-null     int64
#  4   유학/연수   67 non-null     int64
#  5   기타      67 non-null     int64
#  6   계       67 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 3.8+ KB

# %%
kto_201901.describe()
# Out:
#                  관광            상용           공용         유학/연수             기타  \
# count      67.00000     67.000000    67.000000     67.000000      67.000000
# mean    26396.80597    408.208955   132.507463    477.462687    5564.208955
# std    102954.04969   1416.040302   474.406339   2009.484800   17209.438418
# min         0.00000      0.000000     0.000000      0.000000      16.000000
# 25%       505.00000     14.500000     2.500000     17.500000     260.000000
# 50%      1304.00000     45.000000    14.000000     43.000000     912.000000
# 75%      8365.00000    176.500000    38.000000    182.000000    2824.500000
# max    765082.00000  10837.000000  2657.000000  14087.000000  125521.000000
#
#                    계
# count      67.000000
# mean    32979.194030
# std    122821.369969
# min        54.000000
# 25%       927.000000
# 50%      2695.000000
# 75%     14905.500000
# max    916950.000000

# %%
tmp = kto_201901[(kto_201901['관광'] == 0)
                | (kto_201901['상용'] == 0)
                | (kto_201901['공용'] == 0)
                | (kto_201901['유학/연수'] == 0)]
tmp
# Out:
#         국적    관광   상용  공용  유학/연수     기타      계
# 4      마카오  2506    2   0     17     45   2570
# 20    이스라엘   727   12   0      9     57    805
# 22  우즈베키스탄  1958  561   0    407   2828   5754
# 38     스위스   613   18   0     19     97    747
# 45     그리스   481   17   4      0    273    775
# 46    포르투갈   416   14   0     13    121    564
# 51   크로아티아   226   12   0      3    250    491
# 54     폴란드   713   10   0     27    574   1324
# 59  대양주 기타   555    3   4      0     52    614
# 63    기타대륙    33    4   0      1     16     54
# 64    국적미상    33    4   0      1     16     54
# 65    교포소계     0    0   0      0  15526  15526
# 66      교포     0    0   0      0  15526  15526

# %%
len(tmp)
# Out:
# 13

# %%
# 년월에 대한 컬럼 추가
# 컬럼명 : 기준 년월
# 값 : 2019 - 01

kto_201901['기준년월'] = '2019-01'
kto_201901
# Out:
#          국적      관광     상용    공용  유학/연수      기타       계     기준년월
# 0      아시아주  765082  10837  1423  14087  125521  916950  2019-01
# 1        일본  198805   2233   127    785    4576  206526  2019-01
# 2        대만   86393     74    22    180    1285   87954  2019-01
# 3        홍콩   34653     59     2     90    1092   35896  2019-01
# 4       마카오    2506      2     0     17      45    2570  2019-01
# ..      ...     ...    ...   ...    ...     ...     ...      ...
# 62  아프리카 기타     768    718    90    206     908    2690  2019-01
# 63     기타대륙      33      4     0      1      16      54  2019-01
# 64     국적미상      33      4     0      1      16      54  2019-01
# 65     교포소계       0      0     0      0   15526   15526  2019-01
# 66       교포       0      0     0      0   15526   15526  2019-01
#
# [67 rows x 8 columns]

# %%
kto_201901
# Out:
#          국적      관광     상용    공용  유학/연수      기타       계     기준년월
# 0      아시아주  765082  10837  1423  14087  125521  916950  2019-01
# 1        일본  198805   2233   127    785    4576  206526  2019-01
# 2        대만   86393     74    22    180    1285   87954  2019-01
# 3        홍콩   34653     59     2     90    1092   35896  2019-01
# 4       마카오    2506      2     0     17      45    2570  2019-01
# ..      ...     ...    ...   ...    ...     ...     ...      ...
# 62  아프리카 기타     768    718    90    206     908    2690  2019-01
# 63     기타대륙      33      4     0      1      16      54  2019-01
# 64     국적미상      33      4     0      1      16      54  2019-01
# 65     교포소계       0      0     0      0   15526   15526  2019-01
# 66       교포       0      0     0      0   15526   15526  2019-01
#
# [67 rows x 8 columns]

# %%
kto_201901['국적'].unique()
# Out:
# array(['아시아주', '일본', '대만', '홍콩', '마카오', '태국', '말레이시아', '필리핀', '인도네시아',
#        '싱가포르', '미얀마', '베트남', '인도', '스리랑카', '파키스탄', '방글라데시', '캄보디아', '몽골',
#        '중국', '이란', '이스라엘', '터키', '우즈베키스탄', '카자흐스탄', 'GCC', '아시아 기타', '미주',
#        '미국', '캐나다', '멕시코', '브라질', '미주 기타', '구주', '영국', '독일', '프랑스',
#        '네덜란드', '스웨덴', '스위스', '이탈리아', '덴마크', '노르웨이', '벨기에', '오스트리아', '스페인',
#        '그리스', '포르투갈', '핀란드', '아일랜드', '우크라이나', '러시아', '크로아티아', '루마니아',
#        '불가리아', '폴란드', '구주 기타', '대양주', '오스트레일리아', '뉴질랜드', '대양주 기타',
#        '아프리카주', '남아프리카공화국', '아프리카 기타', '기타대륙', '국적미상', '교포소계', '교포'],
#       dtype=object)

# %%
# 기준이 없으면 만든다
continents = ['아시아주', '미주', '구주', '대양주', '아프리카주', '기타대륙', '교포소계']
continents
# Out:
# ['아시아주', '미주', '구주', '대양주', '아프리카주', '기타대륙', '교포소계']

# %%
# isin() 안에 있냐?
condition = kto_201901['국적'].isin(continents)
kto_201901[condition == False]
# Out:
#           국적      관광    상용    공용  유학/연수     기타       계     기준년월
# 1         일본  198805  2233   127    785   4576  206526  2019-01
# 2         대만   86393    74    22    180   1285   87954  2019-01
# 3         홍콩   34653    59     2     90   1092   35896  2019-01
# 4        마카오    2506     2     0     17     45    2570  2019-01
# 5         태국   34004    37   199     96   6998   41334  2019-01
# 6      말레이시아   19043    95     7     99   2821   22065  2019-01
# 7        필리핀   14279   211   161    184  15638   30473  2019-01
# 8      인도네시아   14183   136    38    187   4298   18842  2019-01
# 9       싱가포르    8372    94     8     48   1333    9855  2019-01
# 10       미얀마    1304    10    31     67   3877    5289  2019-01
# 11       베트남   10739   763   110   1667   6904   20183  2019-01
# 12        인도    2318  2656    46    177   3474    8671  2019-01
# 13      스리랑카     157    54     5     28   1043    1287  2019-01
# 14      파키스탄     238   178    10    193    413    1032  2019-01
# ...

# %%
kto_201901_ff = kto_201901[condition == False]
kto_201901_ff
# Out:
#           국적      관광    상용    공용  유학/연수     기타       계     기준년월
# 1         일본  198805  2233   127    785   4576  206526  2019-01
# 2         대만   86393    74    22    180   1285   87954  2019-01
# 3         홍콩   34653    59     2     90   1092   35896  2019-01
# 4        마카오    2506     2     0     17     45    2570  2019-01
# 5         태국   34004    37   199     96   6998   41334  2019-01
# 6      말레이시아   19043    95     7     99   2821   22065  2019-01
# 7        필리핀   14279   211   161    184  15638   30473  2019-01
# 8      인도네시아   14183   136    38    187   4298   18842  2019-01
# 9       싱가포르    8372    94     8     48   1333    9855  2019-01
# 10       미얀마    1304    10    31     67   3877    5289  2019-01
# 11       베트남   10739   763   110   1667   6904   20183  2019-01
# 12        인도    2318  2656    46    177   3474    8671  2019-01
# 13      스리랑카     157    54     5     28   1043    1287  2019-01
# 14      파키스탄     238   178    10    193    413    1032  2019-01
# ...

# %%
kto_201901_nat_index = kto_201901_ff.reset_index(drop = True)
kto_201901_nat_index
# Out:
#           국적      관광    상용    공용  유학/연수     기타       계     기준년월
# 0         일본  198805  2233   127    785   4576  206526  2019-01
# 1         대만   86393    74    22    180   1285   87954  2019-01
# 2         홍콩   34653    59     2     90   1092   35896  2019-01
# 3        마카오    2506     2     0     17     45    2570  2019-01
# 4         태국   34004    37   199     96   6998   41334  2019-01
# 5      말레이시아   19043    95     7     99   2821   22065  2019-01
# 6        필리핀   14279   211   161    184  15638   30473  2019-01
# 7      인도네시아   14183   136    38    187   4298   18842  2019-01
# 8       싱가포르    8372    94     8     48   1333    9855  2019-01
# 9        미얀마    1304    10    31     67   3877    5289  2019-01
# 10       베트남   10739   763   110   1667   6904   20183  2019-01
# 11        인도    2318  2656    46    177   3474    8671  2019-01
# 12      스리랑카     157    54     5     28   1043    1287  2019-01
# 13      파키스탄     238   178    10    193    413    1032  2019-01
# ...

# %%
kto_201901_nat_index
# Out:
#           국적      관광    상용    공용  유학/연수     기타       계     기준년월
# 0         일본  198805  2233   127    785   4576  206526  2019-01
# 1         대만   86393    74    22    180   1285   87954  2019-01
# 2         홍콩   34653    59     2     90   1092   35896  2019-01
# 3        마카오    2506     2     0     17     45    2570  2019-01
# 4         태국   34004    37   199     96   6998   41334  2019-01
# 5      말레이시아   19043    95     7     99   2821   22065  2019-01
# 6        필리핀   14279   211   161    184  15638   30473  2019-01
# 7      인도네시아   14183   136    38    187   4298   18842  2019-01
# 8       싱가포르    8372    94     8     48   1333    9855  2019-01
# 9        미얀마    1304    10    31     67   3877    5289  2019-01
# 10       베트남   10739   763   110   1667   6904   20183  2019-01
# 11        인도    2318  2656    46    177   3474    8671  2019-01
# 12      스리랑카     157    54     5     28   1043    1287  2019-01
# 13      파키스탄     238   178    10    193    413    1032  2019-01
# ...

# %%
# 대륙 컬럼을 만들어 국가의 대륙을 표시

# %%
kto_201901['국적'].unique()
# Out:
# array(['아시아주', '일본', '대만', '홍콩', '마카오', '태국', '말레이시아', '필리핀', '인도네시아',
#        '싱가포르', '미얀마', '베트남', '인도', '스리랑카', '파키스탄', '방글라데시', '캄보디아', '몽골',
#        '중국', '이란', '이스라엘', '터키', '우즈베키스탄', '카자흐스탄', 'GCC', '아시아 기타', '미주',
#        '미국', '캐나다', '멕시코', '브라질', '미주 기타', '구주', '영국', '독일', '프랑스',
#        '네덜란드', '스웨덴', '스위스', '이탈리아', '덴마크', '노르웨이', '벨기에', '오스트리아', '스페인',
#        '그리스', '포르투갈', '핀란드', '아일랜드', '우크라이나', '러시아', '크로아티아', '루마니아',
#        '불가리아', '폴란드', '구주 기타', '대양주', '오스트레일리아', '뉴질랜드', '대양주 기타',
#        '아프리카주', '남아프리카공화국', '아프리카 기타', '기타대륙', '국적미상', '교포소계', '교포'],
#       dtype=object)

# %%
asia = ['일본', '대만', '홍콩', '마카오', '태국', '말레이시아', '필리핀', '인도네시아',
       '싱가포르', '미얀마', '베트남', '인도', '스리랑카', '파키스탄', '방글라데시', '캄보디아', '몽골',
       '중국', '이란', '이스라엘', '터키', '우즈베키스탄', '카자흐스탄', 'GCC', '아시아 기타']
len(asia)
# Out:
# 25

# %%
ame = ['미국', '캐나다', '멕시코', '브라질', '미주 기타']
len(ame)
# Out:
# 5

# %%
eu = ['영국', '독일', '프랑스',
       '네덜란드', '스웨덴', '스위스', '이탈리아', '덴마크', '노르웨이', '벨기에', '오스트리아', '스페인',
       '그리스', '포르투갈', '핀란드', '아일랜드', '우크라이나', '러시아', '크로아티아', '루마니아',
       '불가리아', '폴란드', '구주 기타']
len(eu)
# Out:
# 23

# %%
oce = ['오스트레일리아', '뉴질랜드', '대양주 기타']
len(oce)
# Out:
# 3

# %%
afr = ['남아프리카공화국', '아프리카 기타']
len(afr)
# Out:
# 2

# %%
len(afr) + len(oce) + len(ame) + len(asia) + len(eu)
# Out:
# 58

# %%
connames = ['아시아'] * 25 + ['아메리카'] * 5 + ['유럽'] * 23 + ['오세아니아'] * 3\
+ ['아프리카'] * 2 + ['기타대륙'] + ['교포']
connames
# Out:
# ['아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아시아',
#  '아메리카',
#  '아메리카',
#  '아메리카',
#  '아메리카',
#  '아메리카',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '유럽',
#  '오세아니아',
#  '오세아니아',
#  '오세아니아',
#  '아프리카',
#  '아프리카',
#  '기타대륙',
#  '교포']

# %%
kto_201901_nat_index['대륙'] = connames
kto_201901_nat_index.head()
# Out:
#     국적      관광    상용   공용  유학/연수    기타       계     기준년월   대륙
# 0   일본  198805  2233  127    785  4576  206526  2019-01  아시아
# 1   대만   86393    74   22    180  1285   87954  2019-01  아시아
# 2   홍콩   34653    59    2     90  1092   35896  2019-01  아시아
# 3  마카오    2506     2    0     17    45    2570  2019-01  아시아
# 4   태국   34004    37  199     96  6998   41334  2019-01  아시아

# %%
kto_201901_nat_index['관광객비율(%)'] = round(kto_201901_nat_index['관광'] / kto_201901_nat_index['계'] * 100, 1)
kto_201901_nat_index
# Out:
#           국적      관광    상용    공용  유학/연수     기타       계     기준년월     대륙  \
# 0         일본  198805  2233   127    785   4576  206526  2019-01    아시아
# 1         대만   86393    74    22    180   1285   87954  2019-01    아시아
# 2         홍콩   34653    59     2     90   1092   35896  2019-01    아시아
# 3        마카오    2506     2     0     17     45    2570  2019-01    아시아
# 4         태국   34004    37   199     96   6998   41334  2019-01    아시아
# 5      말레이시아   19043    95     7     99   2821   22065  2019-01    아시아
# 6        필리핀   14279   211   161    184  15638   30473  2019-01    아시아
# 7      인도네시아   14183   136    38    187   4298   18842  2019-01    아시아
# 8       싱가포르    8372    94     8     48   1333    9855  2019-01    아시아
# 9        미얀마    1304    10    31     67   3877    5289  2019-01    아시아
# 10       베트남   10739   763   110   1667   6904   20183  2019-01    아시아
# 11        인도    2318  2656    46    177   3474    8671  2019-01    아시아
# ...

# %%
sum(kto_201901_nat_index['관광'])
# Out:
# 884293

# %%
kto_201901_nat_index['전체비율(%)'] = round(kto_201901_nat_index['관광'] / sum(kto_201901_nat_index['관광']) * 100, 1)
kto_201901_nat_index
# Out:
#           국적      관광    상용    공용  유학/연수     기타       계     기준년월     대륙  \
# 0         일본  198805  2233   127    785   4576  206526  2019-01    아시아
# 1         대만   86393    74    22    180   1285   87954  2019-01    아시아
# 2         홍콩   34653    59     2     90   1092   35896  2019-01    아시아
# 3        마카오    2506     2     0     17     45    2570  2019-01    아시아
# 4         태국   34004    37   199     96   6998   41334  2019-01    아시아
# 5      말레이시아   19043    95     7     99   2821   22065  2019-01    아시아
# 6        필리핀   14279   211   161    184  15638   30473  2019-01    아시아
# 7      인도네시아   14183   136    38    187   4298   18842  2019-01    아시아
# 8       싱가포르    8372    94     8     48   1333    9855  2019-01    아시아
# 9        미얀마    1304    10    31     67   3877    5289  2019-01    아시아
# 10       베트남   10739   763   110   1667   6904   20183  2019-01    아시아
# 11        인도    2318  2656    46    177   3474    8671  2019-01    아시아
# ...

# %%
kto_201901_nat_index.sort_values('전체비율(%)', ascending = False).head()
# Out:
#     국적      관광    상용    공용  유학/연수     기타       계     기준년월    대륙  관광객비율(%)  \
# 17  중국  320113  2993   138   8793  60777  392814  2019-01   아시아      81.5
# 0   일본  198805  2233   127    785   4576  206526  2019-01   아시아      96.3
# 1   대만   86393    74    22    180   1285   87954  2019-01   아시아      98.2
# 25  미국   42989   418  2578    229  16523   62737  2019-01  아메리카      68.5
# 2   홍콩   34653    59     2     90   1092   35896  2019-01   아시아      96.5
#
#     전체비율(%)
# 17     36.2
# 0      22.5
# 1       9.8
# 25      4.9
# 2       3.9

# %%
for i in range(13):
    if i == 0:
        pass
    else:
        print("kto_2010",i,'.xlsx')
# Out:
# kto_2010 1 .xlsx
# kto_2010 2 .xlsx
# kto_2010 3 .xlsx
# kto_2010 4 .xlsx
# kto_2010 5 .xlsx
# kto_2010 6 .xlsx
# kto_2010 7 .xlsx
# kto_2010 8 .xlsx
# kto_2010 9 .xlsx
# kto_2010 10 .xlsx
# kto_2010 11 .xlsx
# kto_2010 12 .xlsx

# %%
list = []
for i in range(13):
    if i == 0 :
        pass
    elif i < 10 :
        list.append('0' + str(i))
    else :
        list.append(str(i))
print(list)
# Out:
# ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

# %%
for i in list :
    print("kto_2010" + i + '.xlsx')
# Out:
# kto_201001.xlsx
# kto_201002.xlsx
# kto_201003.xlsx
# kto_201004.xlsx
# kto_201005.xlsx
# kto_201006.xlsx
# kto_201007.xlsx
# kto_201008.xlsx
# kto_201009.xlsx
# kto_201010.xlsx
# kto_201011.xlsx
# kto_201012.xlsx

# %%
files = []
for i in range(10):
    year = 'kto_201' + str(i)
    for j in range(1, 13):
        if j < 10 :
            print(year + '0' + str(j) + '.xlsx')
            files.append(year + '0' + str(j) + '.xlsx')
        else :
            print(year + str(j) + '.xlsx')
            files.append(year + str(j) + '.xlsx')
# Out:
# kto_201001.xlsx
# kto_201002.xlsx
# kto_201003.xlsx
# kto_201004.xlsx
# kto_201005.xlsx
# kto_201006.xlsx
# kto_201007.xlsx
# kto_201008.xlsx
# kto_201009.xlsx
# kto_201010.xlsx
# kto_201011.xlsx
# kto_201012.xlsx
# kto_201101.xlsx
# kto_201102.xlsx
# kto_201103.xlsx
# kto_201104.xlsx
# kto_201105.xlsx
# kto_201106.xlsx
# kto_201107.xlsx
# kto_201108.xlsx
# kto_201109.xlsx
# kto_201110.xlsx
# kto_201111.xlsx
# kto_201112.xlsx
# kto_201201.xlsx
# kto_201202.xlsx
# kto_201203.xlsx
# kto_201204.xlsx
# kto_201205.xlsx
# kto_201206.xlsx
# kto_201207.xlsx
# kto_201208.xlsx
# kto_201209.xlsx
# kto_201210.xlsx
# kto_201211.xlsx
# kto_201212.xlsx
# kto_201301.xlsx
# kto_201302.xlsx
# kto_201303.xlsx
# kto_201304.xlsx
# kto_201305.xlsx
# kto_201306.xlsx
# kto_201307.xlsx
# kto_201308.xlsx
# kto_201309.xlsx
# kto_201310.xlsx
# kto_201311.xlsx
# kto_201312.xlsx
# kto_201401.xlsx
# kto_201402.xlsx
# kto_201403.xlsx
# kto_201404.xlsx
# kto_201405.xlsx
# kto_201406.xlsx
# kto_201407.xlsx
# ...

# %%
files
# Out:
# ['kto_201001.xlsx',
#  'kto_201002.xlsx',
#  'kto_201003.xlsx',
#  'kto_201004.xlsx',
#  'kto_201005.xlsx',
#  'kto_201006.xlsx',
#  'kto_201007.xlsx',
#  'kto_201008.xlsx',
#  'kto_201009.xlsx',
#  'kto_201010.xlsx',
#  'kto_201011.xlsx',
#  'kto_201012.xlsx',
#  'kto_201101.xlsx',
#  'kto_201102.xlsx',
#  'kto_201103.xlsx',
#  'kto_201104.xlsx',
#  'kto_201105.xlsx',
#  'kto_201106.xlsx',
#  'kto_201107.xlsx',
#  'kto_201108.xlsx',
#  'kto_201109.xlsx',
#  'kto_201110.xlsx',
#  'kto_201111.xlsx',
#  'kto_201112.xlsx',
#  'kto_201201.xlsx',
#  'kto_201202.xlsx',
#  'kto_201203.xlsx',
#  'kto_201204.xlsx',
#  'kto_201205.xlsx',
#  'kto_201206.xlsx',
#  'kto_201207.xlsx',
#  'kto_201208.xlsx',
#  'kto_201209.xlsx',
#  'kto_201210.xlsx',
#  'kto_201211.xlsx',
#  'kto_201212.xlsx',
#  'kto_201301.xlsx',
#  'kto_201302.xlsx',
#  'kto_201303.xlsx',
#  'kto_201304.xlsx',
#  'kto_201305.xlsx',
#  'kto_201306.xlsx',
#  'kto_201307.xlsx',
#  'kto_201308.xlsx',
#  'kto_201309.xlsx',
# ...

# %%
del files[-4:]

# %%
files
# Out:
# ['kto_201001.xlsx',
#  'kto_201002.xlsx',
#  'kto_201003.xlsx',
#  'kto_201004.xlsx',
#  'kto_201005.xlsx',
#  'kto_201006.xlsx',
#  'kto_201007.xlsx',
#  'kto_201008.xlsx',
#  'kto_201009.xlsx',
#  'kto_201010.xlsx',
#  'kto_201011.xlsx',
#  'kto_201012.xlsx',
#  'kto_201101.xlsx',
#  'kto_201102.xlsx',
#  'kto_201103.xlsx',
#  'kto_201104.xlsx',
#  'kto_201105.xlsx',
#  'kto_201106.xlsx',
#  'kto_201107.xlsx',
#  'kto_201108.xlsx',
#  'kto_201109.xlsx',
#  'kto_201110.xlsx',
#  'kto_201111.xlsx',
#  'kto_201112.xlsx',
#  'kto_201201.xlsx',
#  'kto_201202.xlsx',
#  'kto_201203.xlsx',
#  'kto_201204.xlsx',
#  'kto_201205.xlsx',
#  'kto_201206.xlsx',
#  'kto_201207.xlsx',
#  'kto_201208.xlsx',
#  'kto_201209.xlsx',
#  'kto_201210.xlsx',
#  'kto_201211.xlsx',
#  'kto_201212.xlsx',
#  'kto_201301.xlsx',
#  'kto_201302.xlsx',
#  'kto_201303.xlsx',
#  'kto_201304.xlsx',
#  'kto_201305.xlsx',
#  'kto_201306.xlsx',
#  'kto_201307.xlsx',
#  'kto_201308.xlsx',
#  'kto_201309.xlsx',
# ...

# %%
files[0]
# Out:
# 'kto_201001.xlsx'

# %%
'./files/'+files[0]
# Out:
# './files/kto_201001.xlsx'

# %%
for i in range(116):
    file_path = './files/' + files[i]
    df = pd.read_excel(file_path
                           , header = 1
                           , skipfooter = 4
                           , usecols = 'A:G')
    print(files[i], '파일의 행은', len(df), '개입니다.')
# Out:
# kto_201001.xlsx 파일의 행은 67 개입니다.
# kto_201002.xlsx 파일의 행은 67 개입니다.
# kto_201003.xlsx 파일의 행은 67 개입니다.
# kto_201004.xlsx 파일의 행은 67 개입니다.
# kto_201005.xlsx 파일의 행은 67 개입니다.
# kto_201006.xlsx 파일의 행은 67 개입니다.
# kto_201007.xlsx 파일의 행은 67 개입니다.
# kto_201008.xlsx 파일의 행은 67 개입니다.
# kto_201009.xlsx 파일의 행은 67 개입니다.
# kto_201010.xlsx 파일의 행은 67 개입니다.
# kto_201011.xlsx 파일의 행은 67 개입니다.
# kto_201012.xlsx 파일의 행은 67 개입니다.
# kto_201101.xlsx 파일의 행은 67 개입니다.
# kto_201102.xlsx 파일의 행은 67 개입니다.
# kto_201103.xlsx 파일의 행은 67 개입니다.
# kto_201104.xlsx 파일의 행은 67 개입니다.
# kto_201105.xlsx 파일의 행은 67 개입니다.
# kto_201106.xlsx 파일의 행은 67 개입니다.
# kto_201107.xlsx 파일의 행은 67 개입니다.
# kto_201108.xlsx 파일의 행은 67 개입니다.
# kto_201109.xlsx 파일의 행은 67 개입니다.
# kto_201110.xlsx 파일의 행은 67 개입니다.
# kto_201111.xlsx 파일의 행은 67 개입니다.
# kto_201112.xlsx 파일의 행은 67 개입니다.
# kto_201201.xlsx 파일의 행은 67 개입니다.
# kto_201202.xlsx 파일의 행은 67 개입니다.
# kto_201203.xlsx 파일의 행은 67 개입니다.
# kto_201204.xlsx 파일의 행은 67 개입니다.
# kto_201205.xlsx 파일의 행은 67 개입니다.
# ...

# %%
# '.files/kro_{}{}.xlsx'.format(yy, str(mm).zfill(2))

# %%
len(files)
# Out:
# 116

# %%
# for yy in range(2010, 2020) :
#    for mm in range(1, 13) :
#        file_path = "./files/kto_{}{}.xlsx".format(yy, str(mm).zfill(2))
#        df = pd.read_excel(file_path, header=1, skipfooter=4, usecols="A:G")
#        print(len(df))
